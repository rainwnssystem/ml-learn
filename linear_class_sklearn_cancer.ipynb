# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn import linear_model
from sklearn.metrics import accuracy_score,classification_report

# %%
df = pd.read_csv('./datasets/breast_cancer.csv')
print(df.shape)  # row 수 확인
print(df.isnull().sum())  # Null 존재 col 확인
df.head()
# Out:
# (272, 10)
# age             0
# mefalsepause    0
# tumor-size      0
# inv-falsedes    0
# falsede-caps    8
# deg-malig       0
# breast          0
# breast-quad     1
# irradiat        0
# class           0
# dtype: int64
#      age mefalsepause tumor-size inv-falsedes falsede-caps  deg-malig breast  \
# 0  40-49   premefalse      15-19          0-2         True          3  right
# 1  50-59         ge40      15-19          0-2        False          1  right
# 2  50-59         ge40      35-39          0-2        False          2   left
# 3  40-49   premefalse      35-39          0-2         True          3  right
# 4  40-49   premefalse      30-34          3-5         True          2   left
#
#   breast-quad  irradiat                    class
# 0     left_up     False        recurrence-events
# 1     central     False  false-recurrence-events
# 2    left_low     False        recurrence-events
# 3    left_low      True  false-recurrence-events
# 4    right_up     False        recurrence-events

# %%
df.dropna(inplace=True)
df.shape # 263
# Out:
# (263, 10)

# %%
plt.figure(figsize=(5, 4))
sns.countplot(x='class', data=df)
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
print(df['class'].value_counts())
# Out:
# class
# false-recurrence-events    186
# recurrence-events           77
# Name: count, dtype: int64

# %%
# Encoding

cat_cols = ['age', 'breast', 'tumor-size', 'inv-falsedes', 'mefalsepause', 'breast-quad']
le = LabelEncoder()
for col in cat_cols:
  df[col] = le.fit_transform(df[col])

# %%
x = df.drop(columns='class').values
y = df['class'].values
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42, stratify=y)

# %%
# Scaling

scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
model = linear_model.LogisticRegression()
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(x_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.7547169811320755

# %%
print(classification_report(y_test, y_pred))
# Out:
#                          precision    recall  f1-score   support
#
# false-recurrence-events       0.80      0.86      0.83        37
#       recurrence-events       0.62      0.50      0.55        16
#
#                accuracy                           0.75        53
#               macro avg       0.71      0.68      0.69        53
#            weighted avg       0.74      0.75      0.75        53

# %%
model = linear_model.RidgeClassifier()
model.fit(x_train, y_train)
# Out:
# RidgeClassifier()

# %%
y_pred = model.predict(x_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.7547169811320755

# %%
print(classification_report(y_test, y_pred))
# Out:
#                          precision    recall  f1-score   support
#
# false-recurrence-events       0.80      0.86      0.83        37
#       recurrence-events       0.62      0.50      0.55        16
#
#                accuracy                           0.75        53
#               macro avg       0.71      0.68      0.69        53
#            weighted avg       0.74      0.75      0.75        53

# %%
model = linear_model.SGDClassifier()
model.fit(x_train, y_train)
# Out:
# SGDClassifier()

# %%
y_pred = model.predict(x_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.4716981132075472

# %%
print(classification_report(y_test, y_pred))
# Out:
#                          precision    recall  f1-score   support
#
# false-recurrence-events       0.66      0.51      0.58        37
#       recurrence-events       0.25      0.38      0.30        16
#
#                accuracy                           0.47        53
#               macro avg       0.45      0.44      0.44        53
#            weighted avg       0.53      0.47      0.49        53
